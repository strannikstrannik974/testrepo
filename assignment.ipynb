# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Lingdong Kong**<br>
# Student

# %% [markdown]
# *I am interested in machine learning because its cool!*

# %% [markdown]
# ### Calculate the sum of 5 plus 12

# %%
5 + 12
# Out:
# 17

# %% [markdown]
# Hello everyone!<br>
# This is my assignment.
#
# The answer is ~~wrong~~ **correct** !
#
# * Thanks
# * for
# * watching
# * : )
#
# | How           | Are           | You   |
# | ------------- |:-------------:| -----:|
# | coursera      | I             | How   |
# | is            | love          | about |
# | so good       | it            | you   |
